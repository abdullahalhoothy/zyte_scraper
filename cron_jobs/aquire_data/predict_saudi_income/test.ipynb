# %%
from pipeline import *

# %%
# Training pipeline
# it requires the zad file to be in the cache
db_string, city = ("postgresql://scraper_user:scraper@37.27.195.216:5432/dbo_operational", ["الرياض", "Riyadh"])
income_data = get_dataset(db_string, city)
models = train_model(income_data) 
#it will save everything to the the model's directory
# Out:
# Fold 1:
#   Train MAE: 0.9928, R²: 0.6061
#   Val   MAE: 1.4901, R²: -0.0584
#
# Fold 2:
#   Train MAE: 1.4833, R²: 0.2430
#   Val   MAE: 1.6957, R²: 0.0498
#
# Fold 3:
#   Train MAE: 0.8540, R²: 0.6951
#   Val   MAE: 1.2957, R²: 0.1950
#
# Fold 4:
#   Train MAE: 0.9867, R²: 0.6066
#   Val   MAE: 1.3837, R²: 0.0390
#
# Fold 5:
#   Train MAE: 0.7917, R²: 0.6270
#   Val   MAE: 1.9161, R²: 0.0208
#
# Fold 6:
#   Train MAE: 1.5654, R²: 0.1852
#   Val   MAE: 1.6381, R²: 0.0057
#
# Fold 7:
#   Train MAE: 0.7854, R²: 0.6496
#   Val   MAE: 1.9117, R²: -0.0923
#
# Fold 8:
#   Train MAE: 0.8192, R²: 0.6818
#   Val   MAE: 1.6047, R²: 0.0681
#
# Fold 9:
#   Train MAE: 0.8879, R²: 0.6421
#   Val   MAE: 1.6440, R²: 0.0551
#
# Fold 10:
#   Train MAE: 1.2689, R²: 0.4975
#   Val   MAE: 1.2647, R²: -0.2485
#
# Fold 11:
#   Train MAE: 0.6139, R²: 0.7703
#   Val   MAE: 2.0010, R²: 0.0386
#
# Fold 12:
#   Train MAE: 1.0154, R²: 0.5850
#   Val   MAE: 1.4699, R²: -0.1054
#
# Fold 13:
#   Train MAE: 1.0199, R²: 0.5737
#   Val   MAE: 1.6086, R²: -0.1260
#
# Fold 14:
#   Train MAE: 1.3154, R²: 0.4644
#   Val   MAE: 1.2288, R²: -0.2721
#
# Fold 15:
#   Train MAE: 1.1301, R²: 0.4584
#   Val   MAE: 1.6620, R²: 0.0781
#
# Fold 16:
#   Train MAE: 1.1475, R²: 0.4947
#   Val   MAE: 1.4163, R²: 0.0303
#
# Fold 17:
#   Train MAE: 1.1183, R²: 0.4678
#   Val   MAE: 1.5385, R²: 0.0195
#
# Fold 18:
#   Train MAE: 1.1229, R²: 0.5657
#   Val   MAE: 1.3202, R²: 0.1585
#
# Fold 19:
#   Train MAE: 1.2944, R²: 0.3368
#   Val   MAE: 1.8068, R²: -0.0630
#
# Fold 20:
#   Train MAE: 1.0279, R²: 0.4737
#   Val   MAE: 1.9204, R²: 0.0320
#
# Fold 21:
#   Train MAE: 0.9903, R²: 0.4674
#   Val   MAE: 1.9025, R²: -0.0347
#
# Fold 22:
#   Train MAE: 0.9343, R²: 0.6438
#   Val   MAE: 1.2734, R²: 0.0942
#
# Fold 23:
#   Train MAE: 1.4870, R²: 0.2941
#   Val   MAE: 1.6436, R²: -0.0262
#
# Fold 24:
#   Train MAE: 1.1818, R²: 0.4610
#   Val   MAE: 1.5775, R²: 0.0691
#
# Fold 25:
#   Train MAE: 1.4141, R²: 0.2401
#   Val   MAE: 1.7574, R²: -0.0256
#
# Fold 26:
#   Train MAE: 0.5561, R²: 0.8450
#   Val   MAE: 1.7472, R²: 0.0640
#
# Fold 27:
#   Train MAE: 0.8333, R²: 0.6076
#   Val   MAE: 1.9264, R²: -0.0954
#
# Fold 28:
#   Train MAE: 0.7613, R²: 0.7794
#   Val   MAE: 1.0897, R²: 0.3457
#
# Fold 29:
#   Train MAE: 1.3543, R²: 0.4366
#   Val   MAE: 1.0613, R²: -0.0558
#
# Fold 30:
#   Train MAE: 0.9440, R²: 0.6062
#   Val   MAE: 1.5845, R²: 0.1005
#
# Fold 31:
#   Train MAE: 1.0300, R²: 0.5368
#   Val   MAE: 1.5188, R²: -0.0109
#
# Fold 32:
#   Train MAE: 1.2127, R²: 0.3231
#   Val   MAE: 1.8444, R²: -0.0269
#
# Fold 33:
#   Train MAE: 0.8604, R²: 0.6701
#   Val   MAE: 1.6732, R²: -0.0419
#
# Fold 34:
#   Train MAE: 1.3317, R²: 0.4194
#   Val   MAE: 1.4748, R²: 0.0314
#
# Fold 35:
#   Train MAE: 1.2217, R²: 0.4368
#   Val   MAE: 1.6842, R²: 0.0086
#
# Fold 36:
#   Train MAE: 0.9535, R²: 0.6902
#   Val   MAE: 0.9479, R²: -0.2380
#
# Fold 37:
#   Train MAE: 1.3937, R²: 0.3801
#   Val   MAE: 1.4068, R²: -0.0942
#
# Fold 38:
#   Train MAE: 0.7026, R²: 0.7093
#   Val   MAE: 1.8749, R²: 0.0110
#
# Fold 39:
#   Train MAE: 1.0351, R²: 0.4786
#   Val   MAE: 1.8628, R²: 0.1184
#
# Fold 40:
#   Train MAE: 0.6305, R²: 0.8109
#   Val   MAE: 1.5057, R²: 0.1327
#
# Fold 41:
#   Train MAE: 0.6786, R²: 0.7419
#   Val   MAE: 1.8075, R²: 0.0962
#
# Fold 42:
#   Train MAE: 0.7572, R²: 0.7766
#   Val   MAE: 1.1138, R²: -0.0280
#
# Fold 43:
#   Train MAE: 1.2444, R²: 0.4172
#   Val   MAE: 1.7293, R²: -0.0905
#
# Fold 44:
#   Train MAE: 1.0359, R²: 0.5228
#   Val   MAE: 1.5083, R²: 0.0732
#
# Fold 45:
#   Train MAE: 1.2534, R²: 0.4294
#   Val   MAE: 1.5558, R²: 0.0173
#
# Fold 46:
#   Train MAE: 1.0638, R²: 0.5110
#   Val   MAE: 1.5539, R²: -0.1716
#
# Fold 47:
#   Train MAE: 0.8303, R²: 0.7099
#   Val   MAE: 1.4004, R²: 0.2004
#
# Fold 48:
#   Train MAE: 0.9009, R²: 0.6989
#   Val   MAE: 1.1360, R²: 0.2165
#
# Fold 49:
#   Train MAE: 1.0769, R²: 0.5092
#   Val   MAE: 1.7153, R²: 0.0018
#
# Fold 50:
#   Train MAE: 1.0656, R²: 0.4274
#   Val   MAE: 1.8798, R²: 0.0622
#
# === Cross-Validation Summary ===
# Mean Train MAE: 1.0395, R²: 0.5441
# Mean Val   MAE: 1.5715, R²: 0.0106

# %%
# Evaluation pipeline
db_string, city = ("postgresql://scraper_user:scraper@37.27.195.216:5432/dbo_operational", ["الرياض", "Riyadh"])
income_data = get_predicted_income(db_string, city)

# %%
population_data = gpd.GeoDataFrame.from_features(
        pd.read_json("all_features_v8.json").features
    )
adapt(income_data, population_data)
